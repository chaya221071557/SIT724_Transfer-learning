# %%
# !pip install torchvision --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.19.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.4.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.4.0+cu121)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchvision) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchvision) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchvision) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchvision) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.4.0->torchvision) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.4.0->torchvision) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.4.0->torchvision) (1.3.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import datasets, models, transforms
from sklearn.metrics import precision_score, recall_score, f1_score
from PIL import Image
import os
from collections import Counter

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
num_classes = 26  # Number of classes in the dataset
num_epochs = 50
batch_size = 32
learning_rate = 0.001

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# %%
# Data directories
data_dir = '/content/drive/MyDrive/malevis_train_val_224x224'  # Replacing with the dataset path
train_dir = os.path.join(data_dir, 'train')
val_dir = os.path.join(data_dir, 'val')

# %%
image_datasets = {
    'train': datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'val': datasets.ImageFolder(val_dir, transform=data_transforms['val'])
}

# %%
dataloaders = {
    'train': DataLoader(image_datasets['train'], batch_size=batch_size, shuffle=True, num_workers=4),
    'val': DataLoader(image_datasets['val'], batch_size=batch_size, shuffle=False, num_workers=4)
}

# Load pre-trained AlexNet model
model = models.alexnet(weights=models.AlexNet_Weights.DEFAULT)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 212MB/s]

# %%
# Freeze all the layers except the last fully connected layers
for param in model.parameters():
    param.requires_grad = False

# %%
# Modify the classifier to match the number of classes in the dataset and unfreeze some layers
model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)

# Unfreeze the last convolutional block for fine-tuning
for param in model.features[10:].parameters():
    param.requires_grad = True

# %%
# Move model to device
model = model.to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
import time

# Initialize variables to store the best metrics
best_metrics = {
    'epoch': -1,
    'accuracy': 0.0,
    'precision': 0.0,
    'recall': 0.0,
    'f1_score': 0.0,
    'loss': float('inf')
}

start_time = time.time()

# Training and validation
for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}/{num_epochs}')
    print('-' * 10)

    # Each epoch has a training and validation phase
    for phase in ['train', 'val']:
        if phase == 'train':
            model.train()  # Set model to training mode
        else:
            model.eval()   # Set model to evaluate mode

        running_loss = 0.0
        running_corrects = 0
        all_labels = []
        all_preds = []

        # Iterate over data
        for inputs, labels in dataloaders[phase]:
            inputs = inputs.to(device)
            labels = labels.to(device)

            # Zero the parameter gradients
            optimizer.zero_grad()

            # Forward
            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                # Backward + optimize only if in training phase
                if phase == 'train':
                    loss.backward()
                    optimizer.step()

            # Statistics
            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())

        epoch_loss = running_loss / len(image_datasets[phase])
        epoch_acc = running_corrects.double() / len(image_datasets[phase])

        # Calculate precision, recall, and F1 score
        epoch_precision = precision_score(all_labels, all_preds, average='weighted')
        epoch_recall = recall_score(all_labels, all_preds, average='weighted')
        epoch_f1 = f1_score(all_labels, all_preds, average='weighted')

        print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')
        print(f'{phase} Precision: {epoch_precision:.4f} Recall: {epoch_recall:.4f} F1 Score: {epoch_f1:.4f}')

        # Store the best metrics based on validation accuracy
        if phase == 'val' and epoch_acc > best_metrics['accuracy']:
            best_metrics = {
                'epoch': epoch + 1,
                'accuracy': epoch_acc.item(),
                'precision': epoch_precision,
                'recall': epoch_recall,
                'f1_score': epoch_f1,
                'loss': epoch_loss
            }

elapsed_time = time.time() - start_time
elapsed_mins = int(elapsed_time / 60)
elapsed_secs = int(elapsed_time % 60)

print('Training complete')
print(f'Training complete in {elapsed_mins}m {elapsed_secs}s')
print(f'Best val Acc: {best_metrics["accuracy"]:.4f}')
print(f'Best val Loss: {best_metrics["loss"]:.4f}')
print(f'Best val Precision: {best_metrics["precision"]:.4f}')
print(f'Best val Recall: {best_metrics["recall"]:.4f}')
print(f'Best val F1 Score: {best_metrics["f1_score"]:.4f}')
# Out:
# Epoch 1/50
# ----------
# train Loss: 0.7921 Acc: 0.7887
# train Precision: 0.7829 Recall: 0.7887 F1 Score: 0.7848
# val Loss: 1.0443 Acc: 0.7749
# val Precision: 0.8396 Recall: 0.7749 F1 Score: 0.7738
# Epoch 2/50
# ----------
# train Loss: 0.4061 Acc: 0.8827
# train Precision: 0.8822 Recall: 0.8827 F1 Score: 0.8821
# val Loss: 0.9875 Acc: 0.7616
# val Precision: 0.8495 Recall: 0.7616 F1 Score: 0.7584
# Epoch 3/50
# ----------
# train Loss: 0.3193 Acc: 0.9068
# train Precision: 0.9067 Recall: 0.9068 F1 Score: 0.9066
# val Loss: 1.0520 Acc: 0.7981
# val Precision: 0.8588 Recall: 0.7981 F1 Score: 0.7986
# Epoch 4/50
# ----------
# train Loss: 0.2733 Acc: 0.9182
# train Precision: 0.9182 Recall: 0.9182 F1 Score: 0.9181
# val Loss: 0.8557 Acc: 0.8137
# val Precision: 0.8672 Recall: 0.8137 F1 Score: 0.8140
# Epoch 5/50
# ----------
# train Loss: 0.2475 Acc: 0.9273
# train Precision: 0.9269 Recall: 0.9273 F1 Score: 0.9270
# val Loss: 0.9262 Acc: 0.7938
# val Precision: 0.8597 Recall: 0.7938 F1 Score: 0.7916
# Epoch 6/50
# ----------
# train Loss: 0.2095 Acc: 0.9379
# train Precision: 0.9379 Recall: 0.9379 F1 Score: 0.9378
# val Loss: 0.7768 Acc: 0.8326
# val Precision: 0.8667 Recall: 0.8326 F1 Score: 0.8344
# Epoch 7/50
# ----------
# train Loss: 0.1953 Acc: 0.9399
# train Precision: 0.9400 Recall: 0.9399 F1 Score: 0.9398
# val Loss: 0.9489 Acc: 0.8112
# val Precision: 0.8676 Recall: 0.8112 F1 Score: 0.8090
# Epoch 8/50
# ----------
# train Loss: 0.1896 Acc: 0.9433
# train Precision: 0.9433 Recall: 0.9433 F1 Score: 0.9433
# val Loss: 0.8114 Acc: 0.8281
# val Precision: 0.8762 Recall: 0.8281 F1 Score: 0.8318
# Epoch 9/50
# ----------
# train Loss: 0.1721 Acc: 0.9467
# train Precision: 0.9467 Recall: 0.9467 F1 Score: 0.9466
# val Loss: 1.0232 Acc: 0.8092
# val Precision: 0.8724 Recall: 0.8092 F1 Score: 0.8069
# Epoch 10/50
# ----------
# train Loss: 0.1777 Acc: 0.9443
# train Precision: 0.9442 Recall: 0.9443 F1 Score: 0.9442
# val Loss: 1.0331 Acc: 0.8119
# val Precision: 0.8699 Recall: 0.8119 F1 Score: 0.8093
# Epoch 11/50
# ----------
# train Loss: 0.1541 Acc: 0.9553
# train Precision: 0.9554 Recall: 0.9553 F1 Score: 0.9553
# val Loss: 0.9972 Acc: 0.8236
# val Precision: 0.8692 Recall: 0.8236 F1 Score: 0.8223
# Epoch 12/50
# ----------
# train Loss: 0.1500 Acc: 0.9553
# train Precision: 0.9554 Recall: 0.9553 F1 Score: 0.9553
# val Loss: 1.1661 Acc: 0.8032
# val Precision: 0.8669 Recall: 0.8032 F1 Score: 0.7987
# Epoch 13/50
# ----------
# train Loss: 0.1381 Acc: 0.9559
# train Precision: 0.9562 Recall: 0.9559 F1 Score: 0.9560
# val Loss: 1.2707 Acc: 0.8059
# val Precision: 0.8766 Recall: 0.8059 F1 Score: 0.8083
# Epoch 14/50
# ----------
# train Loss: 0.1537 Acc: 0.9534
# train Precision: 0.9533 Recall: 0.9534 F1 Score: 0.9534
# val Loss: 1.0816 Acc: 0.8168
# val Precision: 0.8733 Recall: 0.8168 F1 Score: 0.8159
# Epoch 15/50
# ----------
# train Loss: 0.1490 Acc: 0.9563
# train Precision: 0.9562 Recall: 0.9563 F1 Score: 0.9562
# val Loss: 1.1265 Acc: 0.8166
# val Precision: 0.8692 Recall: 0.8166 F1 Score: 0.8142
# Epoch 16/50
# ----------
# train Loss: 0.1449 Acc: 0.9575
# train Precision: 0.9574 Recall: 0.9575 F1 Score: 0.9574
# val Loss: 1.1357 Acc: 0.8176
# val Precision: 0.8738 Recall: 0.8176 F1 Score: 0.8175
# Epoch 17/50
# ----------
# train Loss: 0.1272 Acc: 0.9610
# train Precision: 0.9610 Recall: 0.9610 F1 Score: 0.9609
# val Loss: 1.0612 Acc: 0.8352
# val Precision: 0.8813 Recall: 0.8352 F1 Score: 0.8368
# Epoch 18/50
# ----------
# train Loss: 0.1401 Acc: 0.9578
# train Precision: 0.9579 Recall: 0.9578 F1 Score: 0.9578
# val Loss: 1.0665 Acc: 0.8326
# val Precision: 0.8759 Recall: 0.8326 F1 Score: 0.8333
# Epoch 19/50
# ----------
# train Loss: 0.1336 Acc: 0.9604
# train Precision: 0.9603 Recall: 0.9604 F1 Score: 0.9603
# val Loss: 1.0438 Acc: 0.8342
# val Precision: 0.8794 Recall: 0.8342 F1 Score: 0.8361
# Epoch 20/50
# ----------
# train Loss: 0.1276 Acc: 0.9626
# train Precision: 0.9626 Recall: 0.9626 F1 Score: 0.9626
# val Loss: 1.2279 Acc: 0.8149
# val Precision: 0.8722 Recall: 0.8149 F1 Score: 0.8128
# Epoch 21/50
# ----------
# train Loss: 0.1205 Acc: 0.9640
# train Precision: 0.9640 Recall: 0.9640 F1 Score: 0.9640
# val Loss: 1.0904 Acc: 0.8283
# val Precision: 0.8761 Recall: 0.8283 F1 Score: 0.8264
# Epoch 22/50
# ----------
# train Loss: 0.1102 Acc: 0.9666
# train Precision: 0.9666 Recall: 0.9666 F1 Score: 0.9666
# val Loss: 1.3916 Acc: 0.8289
# val Precision: 0.8873 Recall: 0.8289 F1 Score: 0.8302
# Epoch 23/50
# ----------
# train Loss: 0.1187 Acc: 0.9657
# train Precision: 0.9657 Recall: 0.9657 F1 Score: 0.9657
# val Loss: 1.1787 Acc: 0.8430
# val Precision: 0.8892 Recall: 0.8430 F1 Score: 0.8461
# Epoch 24/50
# ----------
# train Loss: 0.1218 Acc: 0.9647
# train Precision: 0.9646 Recall: 0.9647 F1 Score: 0.9646
# val Loss: 1.0810 Acc: 0.8410
# val Precision: 0.8866 Recall: 0.8410 F1 Score: 0.8446
# Epoch 25/50
# ----------
# train Loss: 0.1308 Acc: 0.9626
# train Precision: 0.9627 Recall: 0.9626 F1 Score: 0.9626
# val Loss: 1.1454 Acc: 0.8488
# val Precision: 0.8851 Recall: 0.8488 F1 Score: 0.8526
# Epoch 26/50
# ----------
# train Loss: 0.1266 Acc: 0.9644
# train Precision: 0.9644 Recall: 0.9644 F1 Score: 0.9644
# val Loss: 1.2225 Acc: 0.8314
# val Precision: 0.8871 Recall: 0.8314 F1 Score: 0.8356
# Epoch 27/50
# ----------
# train Loss: 0.1052 Acc: 0.9692
# train Precision: 0.9692 Recall: 0.9692 F1 Score: 0.9692
# val Loss: 1.5380 Acc: 0.8205
# val Precision: 0.8865 Recall: 0.8205 F1 Score: 0.8239
# Epoch 28/50
# ----------
# train Loss: 0.1093 Acc: 0.9671
# train Precision: 0.9671 Recall: 0.9671 F1 Score: 0.9671
# val Loss: 1.5673 Acc: 0.8115
# val Precision: 0.8612 Recall: 0.8115 F1 Score: 0.8065
# Epoch 29/50
# ----------
# train Loss: 0.1336 Acc: 0.9666
# train Precision: 0.9665 Recall: 0.9666 F1 Score: 0.9665
# val Loss: 1.3776 Acc: 0.8250
# val Precision: 0.8892 Recall: 0.8250 F1 Score: 0.8269
# Epoch 30/50
# ----------
# train Loss: 0.1181 Acc: 0.9676
# train Precision: 0.9678 Recall: 0.9676 F1 Score: 0.9677
# val Loss: 1.4145 Acc: 0.8385
# val Precision: 0.8796 Recall: 0.8385 F1 Score: 0.8381
# Epoch 31/50
# ----------
# train Loss: 0.1254 Acc: 0.9668
# train Precision: 0.9667 Recall: 0.9668 F1 Score: 0.9667
# val Loss: 1.3903 Acc: 0.8336
# val Precision: 0.8826 Recall: 0.8336 F1 Score: 0.8332
# Epoch 32/50
# ----------
# train Loss: 0.1068 Acc: 0.9686
# train Precision: 0.9686 Recall: 0.9686 F1 Score: 0.9685
# val Loss: 1.1953 Acc: 0.8336
# val Precision: 0.8837 Recall: 0.8336 F1 Score: 0.8342
# Epoch 33/50
# ----------
# train Loss: 0.0961 Acc: 0.9712
# train Precision: 0.9712 Recall: 0.9712 F1 Score: 0.9712
# val Loss: 1.2626 Acc: 0.8433
# val Precision: 0.8879 Recall: 0.8433 F1 Score: 0.8455
# Epoch 34/50
# ----------
# train Loss: 0.0909 Acc: 0.9733
# train Precision: 0.9733 Recall: 0.9733 F1 Score: 0.9733
# val Loss: 1.2268 Acc: 0.8367
# val Precision: 0.8819 Recall: 0.8367 F1 Score: 0.8388
# Epoch 35/50
# ----------
# train Loss: 0.1260 Acc: 0.9660
# train Precision: 0.9660 Recall: 0.9660 F1 Score: 0.9660
# val Loss: 1.5415 Acc: 0.8318
# val Precision: 0.8853 Recall: 0.8318 F1 Score: 0.8326
# Epoch 36/50
# ----------
# train Loss: 0.1202 Acc: 0.9647
# train Precision: 0.9647 Recall: 0.9647 F1 Score: 0.9647
# val Loss: 1.4238 Acc: 0.8227
# val Precision: 0.8845 Recall: 0.8227 F1 Score: 0.8239
# Epoch 37/50
# ----------
# train Loss: 0.1065 Acc: 0.9697
# train Precision: 0.9697 Recall: 0.9697 F1 Score: 0.9697
# val Loss: 1.6564 Acc: 0.8225
# val Precision: 0.8818 Recall: 0.8225 F1 Score: 0.8214
# Epoch 38/50
# ----------
# train Loss: 0.1294 Acc: 0.9689
# train Precision: 0.9689 Recall: 0.9689 F1 Score: 0.9689
# val Loss: 1.3147 Acc: 0.8480
# val Precision: 0.8909 Recall: 0.8480 F1 Score: 0.8521
# Epoch 39/50
# ----------
# train Loss: 0.1021 Acc: 0.9721
# train Precision: 0.9721 Recall: 0.9721 F1 Score: 0.9721
# val Loss: 1.4512 Acc: 0.8451
# val Precision: 0.8987 Recall: 0.8451 F1 Score: 0.8500
# Epoch 40/50
# ----------
# train Loss: 0.0847 Acc: 0.9771
# train Precision: 0.9772 Recall: 0.9771 F1 Score: 0.9771
# val Loss: 1.2974 Acc: 0.8459
# val Precision: 0.8826 Recall: 0.8459 F1 Score: 0.8475
# Epoch 41/50
# ----------
# train Loss: 0.0977 Acc: 0.9705
# train Precision: 0.9705 Recall: 0.9705 F1 Score: 0.9705
# val Loss: 1.3563 Acc: 0.8445
# val Precision: 0.8924 Recall: 0.8445 F1 Score: 0.8479
# Epoch 42/50
# ----------
# train Loss: 0.1004 Acc: 0.9721
# train Precision: 0.9721 Recall: 0.9721 F1 Score: 0.9721
# val Loss: 1.4520 Acc: 0.8391
# val Precision: 0.8873 Recall: 0.8391 F1 Score: 0.8413
# Epoch 43/50
# ----------
# train Loss: 0.1014 Acc: 0.9730
# train Precision: 0.9729 Recall: 0.9730 F1 Score: 0.9729
# val Loss: 1.7220 Acc: 0.8311
# val Precision: 0.8857 Recall: 0.8311 F1 Score: 0.8321
# Epoch 44/50
# ----------
# train Loss: 0.1240 Acc: 0.9671
# train Precision: 0.9670 Recall: 0.9671 F1 Score: 0.9671
# val Loss: 1.5106 Acc: 0.8330
# val Precision: 0.8959 Recall: 0.8330 F1 Score: 0.8373
# Epoch 45/50
# ----------
# train Loss: 0.0897 Acc: 0.9732
# train Precision: 0.9732 Recall: 0.9732 F1 Score: 0.9732
# val Loss: 1.5025 Acc: 0.8465
# val Precision: 0.8920 Recall: 0.8465 F1 Score: 0.8503
# Epoch 46/50
# ----------
# train Loss: 0.1072 Acc: 0.9737
# train Precision: 0.9737 Recall: 0.9737 F1 Score: 0.9737
# val Loss: 1.3601 Acc: 0.8422
# val Precision: 0.8873 Recall: 0.8422 F1 Score: 0.8459
# Epoch 47/50
# ----------
# train Loss: 0.0934 Acc: 0.9764
# train Precision: 0.9764 Recall: 0.9764 F1 Score: 0.9764
# val Loss: 1.2197 Acc: 0.8494
# val Precision: 0.8948 Recall: 0.8494 F1 Score: 0.8538
# Epoch 48/50
# ----------
# train Loss: 0.0849 Acc: 0.9775
# train Precision: 0.9775 Recall: 0.9775 F1 Score: 0.9775
# val Loss: 1.2685 Acc: 0.8562
# val Precision: 0.8963 Recall: 0.8562 F1 Score: 0.8598
# Epoch 49/50
# ----------
# train Loss: 0.1095 Acc: 0.9712
# train Precision: 0.9712 Recall: 0.9712 F1 Score: 0.9712
# val Loss: 1.4390 Acc: 0.8426
# val Precision: 0.8890 Recall: 0.8426 F1 Score: 0.8467
# Epoch 50/50
# ----------
# train Loss: 0.0846 Acc: 0.9753
# train Precision: 0.9753 Recall: 0.9753 F1 Score: 0.9753
# val Loss: 1.5187 Acc: 0.8435
# val Precision: 0.8915 Recall: 0.8435 F1 Score: 0.8460
# Training complete
# Training complete in 48m 34s
# Best val Acc: 0.8562
# Best val Loss: 1.2685
# Best val Precision: 0.8963
# Best val Recall: 0.8562
# Best val F1 Score: 0.8598

# %%
from PIL import Image

# Prediction function
def predict_image(image_path, model, class_names):
    model.eval()

    # Image transformations
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])

    # Load image and apply transformations
    image = Image.open(image_path).convert('RGB')  # Convert to RGB to ensure 3 channels
    image = transform(image).unsqueeze(0)  # Add batch dimension

    # Move image to device
    image = image.to(device)

    # Make prediction
    with torch.no_grad():
        outputs = model(image)
        _, preds = torch.max(outputs, 1)

    # Get the class name
    predicted_class = class_names[preds.item()]
    return predicted_class

# Example usage
class_names = image_datasets['train'].classes  # Get class names from the training dataset
image_path = '/content/drive/MyDrive/malevis_train_val_224x224/val/Neoreklami/c0fa7411c52094305ef8130c86eeafaf072111d4resized_image.png'  # Replace with the path to your image
predicted_class = predict_image(image_path, model, class_names)
print(f'Predicted class: {predicted_class}')
# Out:
# Predicted class: Neoreklami
